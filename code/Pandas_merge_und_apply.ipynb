# %%
import pandas as pd

# %%
doi_df_journal = pd.DataFrame({
    "DOI": [
        "10.1371/journal.pcbi.1004668",
        "10.21105/joss.01035",
        "10.12688/f1000research.18866.2",
        "10.1038/s41598-019-52881-4",
        "10.1186/s12859-019-3171-0"],
    "journal": [
        "PLoS Comput Biol",
        "JOSS",
        "F1000Res",
        "Sci Rep",
        "BMC Bioinformatics]"]})

doi_df_first_author = pd.DataFrame({
    "DOI": [
        "10.1371/journal.pcbi.1004668",
        "10.21105/joss.01035",
        "10.21105/joss.01006",
        "10.12688/f1000research.18866.2",
        "10.1186/s12859-019-3171-0"],
    "first_author": [
        "Blischak",
        "Sparks",
        "Granger",
        "Thang",
        "Chen]"]})

# %%
doi_df_journal
# Out:
#                               DOI              journal
# 0    10.1371/journal.pcbi.1004668     PLoS Comput Biol
# 1             10.21105/joss.01035                 JOSS
# 2  10.12688/f1000research.18866.2             F1000Res
# 3      10.1038/s41598-019-52881-4              Sci Rep
# 4       10.1186/s12859-019-3171-0  BMC Bioinformatics]

# %%
doi_df_first_author
# Out:
#                               DOI first_author
# 0    10.1371/journal.pcbi.1004668     Blischak
# 1             10.21105/joss.01035       Sparks
# 2             10.21105/joss.01006      Granger
# 3  10.12688/f1000research.18866.2        Thang
# 4       10.1186/s12859-019-3171-0        Chen]

# %%
doi_df_first_author.merge(doi_df_journal, on="DOI")
# Out:
#                               DOI first_author              journal
# 0    10.1371/journal.pcbi.1004668     Blischak     PLoS Comput Biol
# 1             10.21105/joss.01035       Sparks                 JOSS
# 2  10.12688/f1000research.18866.2        Thang             F1000Res
# 3       10.1186/s12859-019-3171-0        Chen]  BMC Bioinformatics]

# %%
doi_df_first_author.merge(doi_df_journal, on="DOI", how="left")
# Out:
#                               DOI first_author              journal
# 0    10.1371/journal.pcbi.1004668     Blischak     PLoS Comput Biol
# 1             10.21105/joss.01035       Sparks                 JOSS
# 2             10.21105/joss.01006      Granger                  NaN
# 3  10.12688/f1000research.18866.2        Thang             F1000Res
# 4       10.1186/s12859-019-3171-0        Chen]  BMC Bioinformatics]

# %%
doi_df_first_author.merge(doi_df_journal, on="DOI", how="right")
# Out:
#                               DOI first_author              journal
# 0    10.1371/journal.pcbi.1004668     Blischak     PLoS Comput Biol
# 1             10.21105/joss.01035       Sparks                 JOSS
# 2  10.12688/f1000research.18866.2        Thang             F1000Res
# 3       10.1186/s12859-019-3171-0        Chen]  BMC Bioinformatics]
# 4      10.1038/s41598-019-52881-4          NaN              Sci Rep

# %%
doi_df_first_author.merge(doi_df_journal, on="DOI", how="inner")
# Out:
#                               DOI first_author              journal
# 0    10.1371/journal.pcbi.1004668     Blischak     PLoS Comput Biol
# 1             10.21105/joss.01035       Sparks                 JOSS
# 2  10.12688/f1000research.18866.2        Thang             F1000Res
# 3       10.1186/s12859-019-3171-0        Chen]  BMC Bioinformatics]

# %%
doi_df_first_author.merge(doi_df_journal, on="DOI", how="outer")
# Out:
#                               DOI first_author              journal
# 0    10.1371/journal.pcbi.1004668     Blischak     PLoS Comput Biol
# 1             10.21105/joss.01035       Sparks                 JOSS
# 2             10.21105/joss.01006      Granger                  NaN
# 3  10.12688/f1000research.18866.2        Thang             F1000Res
# 4       10.1186/s12859-019-3171-0        Chen]  BMC Bioinformatics]
# 5      10.1038/s41598-019-52881-4          NaN              Sci Rep

# %%
openapc = pd.read_csv("https://raw.githubusercontent.com/OpenAPC/openapc-de/master/data/fuberlin/APC_FU_Berlin_2015.csv")

# %%
openapc
# Out:
#    institution  period     euro                            doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00          10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12      10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00             10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00   10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00      10.1186/s13099-015-0075-z      False
# 5    FU Berlin    2015  1191.32   10.1371/journal.pone.0139894      False
# 6    FU Berlin    2015  1236.83   10.1371/journal.pone.0142240      False
# 7    FU Berlin    2015  1499.08       10.3389/fcimb.2015.00067      False
# 8    FU Berlin    2015  1160.25       10.5194/acp-15-6897-2015      False
# 9    FU Berlin    2015  1191.21   10.1371/journal.pone.0140050      False
# 10   FU Berlin    2015  1142.40       10.3389/fpsyg.2015.01137      False
# 11   FU Berlin    2015  1298.29       10.3389/fpsyg.2015.01661      False
# ...

# %%
openapc[openapc.euro >= 2000.0]
# Out:
#    institution  period    euro                            doi  is_hybrid  \
# 0    FU Berlin    2015  2000.0          10.1038/npjqi.2015.10      False
# 2    FU Berlin    2015  2000.0             10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.0   10.1371/journal.ppat.1005246      False
# 12   FU Berlin    2015  2000.0       10.3389/fpsyg.2015.01675      False
# 15   FU Berlin    2015  2000.0   10.1371/journal.ppat.1004781      False
# 23   FU Berlin    2015  2000.0         10.1127/metz/2015/0641      False
# 28   FU Berlin    2015  2000.0       10.3389/fnhum.2015.00551      False
# 29   FU Berlin    2015  2000.0             10.1038/ncomms8606      False
# 32   FU Berlin    2015  2000.0      10.1186/s12918-015-0183-x      False
# 45   FU Berlin    2015  2000.0   10.1371/journal.pcbi.1004200      False
# 60   FU Berlin    2015  2000.0            10.1155/2015/569512      False
#
#                            publisher               journal_full_title  \
# ...

# %%
openapc["high_price"] = openapc["euro"] * 1000000

# %%
openapc
# Out:
#    institution  period     euro                            doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00          10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12      10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00             10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00   10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00      10.1186/s13099-015-0075-z      False
# 5    FU Berlin    2015  1191.32   10.1371/journal.pone.0139894      False
# 6    FU Berlin    2015  1236.83   10.1371/journal.pone.0142240      False
# 7    FU Berlin    2015  1499.08       10.3389/fcimb.2015.00067      False
# 8    FU Berlin    2015  1160.25       10.5194/acp-15-6897-2015      False
# 9    FU Berlin    2015  1191.21   10.1371/journal.pone.0140050      False
# 10   FU Berlin    2015  1142.40       10.3389/fpsyg.2015.01137      False
# 11   FU Berlin    2015  1298.29       10.3389/fpsyg.2015.01661      False
# ...

# %%
def replace_berlin(cell):
    return cell.replace("Berlin", "Buxtehude")


openapc["new_insitution"] = openapc["institution"].apply(replace_berlin)

# %%
openapc
# Out:
#    institution  period     euro                            doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00          10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12      10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00             10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00   10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00      10.1186/s13099-015-0075-z      False
# 5    FU Berlin    2015  1191.32   10.1371/journal.pone.0139894      False
# 6    FU Berlin    2015  1236.83   10.1371/journal.pone.0142240      False
# 7    FU Berlin    2015  1499.08       10.3389/fcimb.2015.00067      False
# 8    FU Berlin    2015  1160.25       10.5194/acp-15-6897-2015      False
# 9    FU Berlin    2015  1191.21   10.1371/journal.pone.0140050      False
# 10   FU Berlin    2015  1142.40       10.3389/fpsyg.2015.01137      False
# 11   FU Berlin    2015  1298.29       10.3389/fpsyg.2015.01661      False
# ...
